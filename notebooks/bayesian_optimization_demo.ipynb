# %%
import pandas as pd 
import numpy as np 
import optuna 
import mlflow 
import time 
import sys 
from pathlib import Path 
sys.path.insert(0,r"C:Users/user.IBRAHIM-IK-SZHE/Meta_LLM_HPO/hyperopt-llm-project/src")
from data.data_preprocessing import  DataPreprocessing
from models.model import BiLSTMForecast
from pipelines.forecasting_pipeline import ForecastingPipeline
from tuning.bo_tuning import BayesianOptimization

# %%
#***********************main Byesian Optimization***************************
TARGET_COLS =['T (degC)', 'rh (%)', 'p (mbar)', 'wv (m/s)']
clean_train = pd.read_csv('C:/Users/user.IBRAHIM-IK-SZHE/Meta_LLM_HPO/hyperopt-llm-project/data/clean_data/clean_train.csv',
    parse_dates=["datetime"],
    index_col="datetime"
    )
clean_test = pd.read_csv('C:/Users/user.IBRAHIM-IK-SZHE/Meta_LLM_HPO/hyperopt-llm-project/data/clean_data/clean_test.csv', 
    parse_dates=["datetime"],
    index_col="datetime"
    )
#---------
bo_model =  BayesianOptimization(clean_train,clean_test,TARGET_COLS)
bo_opt_time = bo_model.run_bo(6)
# Out:
# 2026/01/25 05:44:25 INFO mlflow.tracking.fluent: Experiment with name 'Bayesian_Optimization' does not exist. Creating a new experiment.
# [I 2026-01-25 05:44:25,709] A new study created in memory with name: no-name-776c221e-9c47-4789-b7ef-89e0766af1ea
# Epoch [1/17] Loss: 0.035959 | RMSE: 0.189644
# Epoch [2/17] Loss: 0.017161 | RMSE: 0.131004
# Epoch [3/17] Loss: 0.010270 | RMSE: 0.101341
# Epoch [4/17] Loss: 0.006282 | RMSE: 0.079248
# Epoch [5/17] Loss: 0.004334 | RMSE: 0.065821
# Epoch [6/17] Loss: 0.002991 | RMSE: 0.054668
# Epoch [7/17] Loss: 0.002099 | RMSE: 0.045779
# Epoch [8/17] Loss: 0.001698 | RMSE: 0.041169
# Epoch [9/17] Loss: 0.001430 | RMSE: 0.037769
# Epoch [10/17] Loss: 0.001228 | RMSE: 0.034995
# Epoch [11/17] Loss: 0.001073 | RMSE: 0.032713
# Epoch [12/17] Loss: 0.000953 | RMSE: 0.030822
# Epoch [13/17] Loss: 0.000860 | RMSE: 0.029278
# Epoch [14/17] Loss: 0.000790 | RMSE: 0.028060
# Epoch [15/17] Loss: 0.000741 | RMSE: 0.027159
# Epoch [16/17] Loss: 0.000709 | RMSE: 0.026573
# Epoch [17/17] Loss: 0.000690 | RMSE: 0.026210
# Test RMSE: 1.1170 | SMAPE: 8.31%
# [I 2026-01-25 05:49:40,191] Trial 0 finished with value: 1.1170297250018493 and parameters: {'num_layers': 1, 'lag': 58, 'hidden_size': 126, 'lr': 0.0005182120604022333, 'batch_size': 32, 'epochs': 17, 'optimizer': 'adamax'}. Best is trial 0 with value: 1.1170297250018493.
# Epoch [1/6] Loss: 0.037509 | RMSE: 0.193712
# Epoch [2/6] Loss: 0.012012 | RMSE: 0.109566
# Epoch [3/6] Loss: 0.005813 | RMSE: 0.076171
# Epoch [4/6] Loss: 0.002700 | RMSE: 0.051828
# Epoch [5/6] Loss: 0.001804 | RMSE: 0.042305
# Epoch [6/6] Loss: 0.001462 | RMSE: 0.038049
# Test RMSE: 1.9279 | SMAPE: 12.60%
# [I 2026-01-25 05:50:32,477] Trial 1 finished with value: 1.9278644352798011 and parameters: {'num_layers': 1, 'lag': 38, 'hidden_size': 81, 'lr': 0.0003623165345530821, 'batch_size': 32, 'epochs': 6, 'optimizer': 'adamw'}. Best is trial 0 with value: 1.1170297250018493.
# Epoch [1/6] Loss: 0.029952 | RMSE: 0.173133
# Epoch [2/6] Loss: 0.014136 | RMSE: 0.118898
# Epoch [3/6] Loss: 0.010467 | RMSE: 0.102316
# Epoch [4/6] Loss: 0.008033 | RMSE: 0.089633
# Epoch [5/6] Loss: 0.006619 | RMSE: 0.081351
# Epoch [6/6] Loss: 0.005085 | RMSE: 0.071304
# Test RMSE: 2.7699 | SMAPE: 18.17%
# [I 2026-01-25 05:54:02,302] Trial 2 finished with value: 2.7698660920690417 and parameters: {'num_layers': 3, 'dropout': 0.3435927279521027, 'lag': 49, 'hidden_size': 77, 'lr': 0.004802430658713304, 'batch_size': 128, 'epochs': 6, 'optimizer': 'adagrad'}. Best is trial 0 with value: 1.1170297250018493.
# Epoch [1/11] Loss: 0.031032 | RMSE: 0.176061
# Epoch [2/11] Loss: 0.016965 | RMSE: 0.130077
# Epoch [3/11] Loss: 0.010400 | RMSE: 0.101772
# Epoch [4/11] Loss: 0.007250 | RMSE: 0.084875
# Epoch [5/11] Loss: 0.005439 | RMSE: 0.073402
# Epoch [6/11] Loss: 0.004857 | RMSE: 0.069362
# Epoch [7/11] Loss: 0.004222 | RMSE: 0.064590
# Epoch [8/11] Loss: 0.003558 | RMSE: 0.059211
# Epoch [9/11] Loss: 0.002941 | RMSE: 0.053718
# Epoch [10/11] Loss: 0.002367 | RMSE: 0.048099
# Epoch [11/11] Loss: 0.001872 | RMSE: 0.042718
# Test RMSE: 3.5318 | SMAPE: 16.54%
# [I 2026-01-25 05:58:51,693] Trial 3 finished with value: 3.5317605091557005 and parameters: {'num_layers': 3, 'dropout': 0.3090421004931948, 'lag': 12, 'hidden_size': 118, 'lr': 0.0009488025817103976, 'batch_size': 32, 'epochs': 11, 'optimizer': 'adamax'}. Best is trial 0 with value: 1.1170297250018493.
# Epoch [1/14] Loss: 0.042165 | RMSE: 0.205277
# Epoch [2/14] Loss: 0.042894 | RMSE: 0.206988
# Epoch [3/14] Loss: 0.039760 | RMSE: 0.199213
# Epoch [4/14] Loss: 0.040141 | RMSE: 0.200131
# Epoch [5/14] Loss: 0.039407 | RMSE: 0.198272
# Epoch [6/14] Loss: 0.039060 | RMSE: 0.197384
# Epoch [7/14] Loss: 0.038856 | RMSE: 0.196859
# Epoch [8/14] Loss: 0.038717 | RMSE: 0.196501
# Epoch [9/14] Loss: 0.038615 | RMSE: 0.196238
# Epoch [10/14] Loss: 0.039169 | RMSE: 0.197643
# Epoch [11/14] Loss: 0.038521 | RMSE: 0.195997
# Epoch [12/14] Loss: 0.038148 | RMSE: 0.195088
# Epoch [13/14] Loss: 0.036542 | RMSE: 0.191280
# Epoch [14/14] Loss: 0.027135 | RMSE: 0.164761
# Test RMSE: 6.1784 | SMAPE: 31.85%
# [I 2026-01-25 06:03:28,471] Trial 4 finished with value: 6.178397579367548 and parameters: {'num_layers': 3, 'dropout': 0.44036853254926, 'lag': 68, 'hidden_size': 33, 'lr': 0.008480046636546841, 'batch_size': 128, 'epochs': 14, 'optimizer': 'adam'}. Best is trial 0 with value: 1.1170297250018493.
# Epoch [1/12] Loss: 0.021057 | RMSE: 0.145104
# Epoch [2/12] Loss: 0.009638 | RMSE: 0.098094
# Epoch [3/12] Loss: 0.005837 | RMSE: 0.076277
# Epoch [4/12] Loss: 0.003683 | RMSE: 0.060556
# Epoch [5/12] Loss: 0.002977 | RMSE: 0.054412
# Epoch [6/12] Loss: 0.002629 | RMSE: 0.051115
# Epoch [7/12] Loss: 0.002364 | RMSE: 0.048458
# Epoch [8/12] Loss: 0.002192 | RMSE: 0.046652
# Epoch [9/12] Loss: 0.002042 | RMSE: 0.045016
# Epoch [10/12] Loss: 0.001924 | RMSE: 0.043707
# Epoch [11/12] Loss: 0.001824 | RMSE: 0.042522
# Epoch [12/12] Loss: 0.001739 | RMSE: 0.041536
# Test RMSE: 2.8345 | SMAPE: 13.87%
# [I 2026-01-25 06:09:30,731] Trial 5 finished with value: inf and parameters: {'num_layers': 3, 'dropout': 0.21829587287344887, 'lag': 68, 'hidden_size': 33, 'lr': 0.00026071549209675236, 'batch_size': 32, 'epochs': 12, 'optimizer': 'rmsprop'}. Best is trial 0 with value: 1.1170297250018493.
# Trial 5 failed:
# Optimization took 1505.02 seconds
